# %%
import numpy as np 
import pandas as pd
import requests
import xlsxwriter
import math

# %%
stocks = pd.read_csv('sp_500_stocks.csv')
stocks
# Out:
#     Ticker
# 0      MMM
# 1      AOS
# 2      ABT
# 3     ABBV
# 4     ABMD
# ..     ...
# 499    YUM
# 500   ZBRA
# 501    ZBH
# 502   ZION
# 503    ZTS
#
# [504 rows x 1 columns]

# %%
symbol = 'AAPL'
api_url= f'https://cloud.iexapis.com/stable/stock/{symbol}/quote/?token=sk_cf2fe4e525464a8b8065f4f2f6cc458e'
data = requests.get(api_url).json()
print(data)
# Out:
# {'avgTotalVolume': 95560456, 'calculationPrice': 'close', 'change': -4.61, 'changePercent': -0.03224, 'close': 138.38, 'closeSource': 'official', 'closeTime': 1665777600353, 'companyName': 'Apple Inc', 'currency': 'USD', 'delayedPrice': 138.22, 'delayedPriceTime': 1665777531443, 'extendedChange': -0.3, 'extendedChangePercent': -0.00217, 'extendedPrice': 138.08, 'extendedPriceTime': 1665791999826, 'high': 144.52, 'highSource': '15 minute delayed price', 'highTime': 1665777599999, 'iexAskPrice': None, 'iexAskSize': None, 'iexBidPrice': None, 'iexBidSize': None, 'iexClose': 138.39, 'iexCloseTime': 1665777599005, 'iexLastUpdated': None, 'iexMarketPercent': None, 'iexOpen': 144.3, 'iexOpenTime': 1665754200205, 'iexRealtimePrice': None, 'iexRealtimeSize': None, 'iexVolume': None, 'lastTradeTime': 1665777599999, 'latestPrice': 138.38, 'latestSource': 'Close', 'latestTime': 'October 14, 2022', 'latestUpdate': 1665777600353, 'latestVolume': 88597969, 'low': 138.19, 'lowSource': 'IEX real time
# ...

# %%
price = data['latestPrice']
market_cap = data['marketCap']
my_columns = ['Ticker', 'Stock Price', 'Market Capitalization', 'Number of Shares to Buy']
final_dataframe = pd.DataFrame(columns = my_columns)
final_dataframe
# Out:
# Empty DataFrame
# Columns: [Ticker, Stock Price, Market Capitalization, Number of Shares to Buy]
# Index: []

# %%
final_dataframe.append(
    pd.Series(
        [
            symbol,
            price,
            market_cap,
            'N/A'
        ],
        index = my_columns
        ),
        ignore_index=True
)
# Out:
# C:\Users\tosho\AppData\Local\Temp\ipykernel_5076\4190714010.py:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_dataframe.append(
#   Ticker Stock Price Market Capitalization Number of Shares to Buy
# 0   AAPL      138.38         2223870661760                     N/A

# %%
def chunks(lst, n):
    """ Yield successive n-sized chunks from list."""
    for i in range(0, len(lst), n):
        yield lst[i:i + n]

# %%
symbol_groups = list(chunks(stocks['Ticker'], 100))
symbol_strings = []
for i in range(0, len(symbol_groups)):
    symbol_strings.append(','.join(symbol_groups[i]))
#    print(symbol_strings[i])
final_dataframe = pd.DataFrame(columns = my_columns)

for symbol_string in symbol_strings:
    batch_api_call_url = f'https://cloud.iexapis.com/stable/stock/market/batch?symbols={symbol_string}&types=quote&token=sk_cf2fe4e525464a8b8065f4f2f6cc458e'
    data = requests.get(batch_api_call_url).json()
    for symbol in symbol_string.split(','):
        final_dataframe = final_dataframe.append(
            pd.Series(
            [
                    symbol,
                    data[symbol]['quote']['latestPrice'],
                    data[symbol]['quote']['marketCap'],
                    'N/A'
            ],
            index = my_columns),
            ignore_index=True
        )

final_dataframe
# Out:
# C:\Users\tosho\AppData\Local\Temp\ipykernel_5076\723209233.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_dataframe = final_dataframe.append(
# C:\Users\tosho\AppData\Local\Temp\ipykernel_5076\723209233.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_dataframe = final_dataframe.append(
# C:\Users\tosho\AppData\Local\Temp\ipykernel_5076\723209233.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_dataframe = final_dataframe.append(
# C:\Users\tosho\AppData\Local\Temp\ipykernel_5076\723209233.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_dataframe = final_dataframe.append(
# ...

# %%
portfolio_size = input('Enter the value of your portfolio:')

try:
    val = float(portfolio_size)
    print(val)
except ValueError:
    print("Thats not a number! \n Please try again")
    portfolio_size = input('Enter the value of your portfolio:')
    val = float(portfolio_size)
# Out:
# Enter the value of your portfolio:10000000
# 10000000.0

# %%
position_size = val/len(final_dataframe.index)
for i in range(0, len(final_dataframe.index)) :
    final_dataframe.loc[i, 'Number of Shares to Buy'] = math.floor(position_size/final_dataframe.loc[i, 'Stock Price'])
final_dataframe
#number_of_apple_shares = position_size/500
#print(math.floor(number_of_apple_shares))
# Out:
#     Ticker Stock Price Market Capitalization Number of Shares to Buy
# 0      MMM      113.63           64724094339                     174
# 1      AOS       49.04            6300531843                     404
# 2      ABT      100.91          176715584266                     196
# 3     ABBV      142.94          252731712995                     138
# 4     ABMD      249.28           11373596682                      79
# ..     ...         ...                   ...                     ...
# 499    YUM      106.77           30380599949                     185
# 500   ZBRA      255.61           13238026819                      77
# 501    ZBH      106.91           22431807877                     185
# 502   ZION       50.14            7544634743                     395
# 503    ZTS       145.4           68067347787                     136
#
# [504 rows x 4 columns]

# %%
writer = pd.ExcelWriter('Recommended Trades.xlsx', engine = 'xlsxwriter')
final_dataframe.to_excel(writer,'Recommended Trades', index = False)

# %%
background_color = '#0a0a23'
font_color = '#ffffff'

string_format = writer.book.add_format(
    {
        'font_color': font_color,
        'bg_color': background_color,
        'border': 1
    }
)

dollar_format = writer.book.add_format(
    {
        'num_format': '$0.00',
        'font_color': font_color,
        'bg_color': background_color,
        'border': 1
    }
)

integer_format = writer.book.add_format(
    {
        'num_format':'$0',
        'font_color': font_color,
        'bg_color': background_color,
        'border': 1
    }
)
writer.sheets['Recommended Trades'].set_column('A:A', 18, string_format)
writer.sheets['Recommended Trades'].set_column('B:B', 18, string_format)
writer.sheets['Recommended Trades'].set_column('C:C', 18, string_format)
writer.sheets['Recommended Trades'].set_column('D:D', 18, string_format)
writer.save()
